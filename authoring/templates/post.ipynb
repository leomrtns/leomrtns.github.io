# %% [raw]
# ---
# title: "A notebook note"
# date: 2026-09-08
# description: "A short description."
# categories: [Binfie Notes]
# draft: true
# execute:
#   enabled: false
# ---

# %% [markdown]
# ## A notebook note
#
# Write Markdown and LaTeX here: $p(\theta \mid D)$.

# %%
# Use your preferred kernel. Run cells and save their outputs before publishing.
